# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/airpolution/interpolate_linear.csv', parse_dates = ['측정일자'])
df.head()
# Out:
#         측정일자  동대문구   종로구    중구   성동구   금천구  ...   강북구   양천구   도봉구   은평구   용산구   광진구
# 0 2010-01-01  35.0  36.0  33.0  31.0  33.0  ...  33.0  36.0  31.0  29.0  34.0  32.0
# 1 2010-01-02  50.0  53.0  48.0  51.0  56.0  ...  47.0  62.0  44.0  47.0  51.0  45.0
# 2 2010-01-03  50.0  44.0  48.0  46.0  45.0  ...  44.0  50.0  49.0  47.0  49.0  46.0
# 3 2010-01-04  38.0  43.0  37.0  38.0  38.0  ...  37.0  43.0  33.0  35.0  38.0  34.0
# 4 2010-01-05  49.0  48.0  49.0  50.0  45.0  ...  40.0  53.0  46.0  48.0  51.0  48.0
#
# [5 rows x 26 columns]

# %%
df.index = df['측정일자']
# df.drop('측정일자', axis = 1, inplace = True)

# %%
df
# Out:
#                  측정일자  동대문구   종로구    중구   성동구  ...   양천구   도봉구   은평구   용산구   광진구
# 측정일자                                           ...
# 2010-01-01 2010-01-01  35.0  36.0  33.0  31.0  ...  36.0  31.0  29.0  34.0  32.0
# 2010-01-02 2010-01-02  50.0  53.0  48.0  51.0  ...  62.0  44.0  47.0  51.0  45.0
# 2010-01-03 2010-01-03  50.0  44.0  48.0  46.0  ...  50.0  49.0  47.0  49.0  46.0
# 2010-01-04 2010-01-04  38.0  43.0  37.0  38.0  ...  43.0  33.0  35.0  38.0  34.0
# 2010-01-05 2010-01-05  49.0  48.0  49.0  50.0  ...  53.0  46.0  48.0  51.0  48.0
# ...               ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2020-12-27 2020-12-27  59.0  70.0  75.0  59.0  ...  67.0  61.0  62.0  66.0  61.0
# 2020-12-28 2020-12-28  59.0  66.0  73.0  57.0  ...  65.0  59.0  57.0  52.0  59.0
# 2020-12-29 2020-12-29  60.0  69.0  78.0  60.0  ...  77.0  62.0  65.0  74.0  60.0
# 2020-12-30 2020-12-30  30.0  39.0  38.0  30.0  ...  33.0  30.0  37.0  44.0  32.0
# 2020-12-31 2020-12-31  21.0  28.0  29.0  22.0  ...  29.0  20.0  26.0  34.0  24.0
#
# [4018 rows x 26 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='측정일자', length=4018, freq=None)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.stats.weightstats import ztest

for i in df.columns[1:]:
  result = seasonal_decompose(df[i], model = 'additive', two_sided = True, extrapolate_trend = 'freq')
  r = result.resid.values
  st, p = ztest(r)

  mu, std = result.resid.mean(), result.resid.std()
  print('평균 :', mu, '표준편차 :', std)

  print(f'이상치 {i} : {len(result.resid[(result.resid>mu+ 2.5*std)|(result.resid<mu- 2.5*std)])}')
  
  outlier = df['측정일자'][result.resid[(result.resid>mu+ 2.5*std)|(result.resid<mu- 2.5*std)].index]

  for j in outlier:
    df.loc[df.index == j,  i] = np.nan
# Out:
# 평균 : -0.014577259475214252 표준편차 : 18.65684285002539
# 이상치 동대문구 : 82
# 평균 : -0.014790585223634176 표준편차 : 18.404202641931104
# 이상치 종로구 : 66
# 평균 : -0.017307321136514422 표준편차 : 18.133571178223505
# 이상치 중구 : 85
# 평균 : -0.013612214422849428 표준편차 : 18.37998286422959
# 이상치 성동구 : 83
# 평균 : -0.011675775337507981 표준편차 : 16.669627505403543
# 이상치 금천구 : 83
# 평균 : -0.015495322071083187 표준편차 : 17.571259761098837
# 이상치 송파구 : 77
# 평균 : -0.012802084497309046 표준편차 : 18.627952766405823
# 이상치 관악구 : 89
# 평균 : -0.01702669619365707 표준편차 : 18.229934439763646
# 이상치 강동구 : 87
# 평균 : -0.01280843347791755 표준편차 : 19.315662776934637
# 이상치 서대문구 : 82
# 평균 : -0.018076817586165368 표준편차 : 17.4353485499224
# 이상치 노원구 : 80
# 평균 : -0.012032588047659035 표준편차 : 19.28750477633001
# 이상치 마포구 : 82
# 평균 : -0.012586219156648986 표준편차 : 17.407206495500517
# 이상치 동작구 : 88
# 평균 : -0.01575943966436392 표준편차 : 19.9775611789185
# 이상치 서초구 : 79
# 평균 : -0.013614754015090184 표준편차 : 18.95698119867255
# 이상치 구로구 : 89
# 평균 : -0.01287065348787186 표준편차 : 19.23664588371112
# 이상치 영등포구 : 80
# 평균 : -0.012451620767764453 표준편차 : 18.788529091455356
# 이상치 강남구 : 83
# 평균 : -0.01620386830690173 표준편차 : 18.74566966625135
# 이상치 강서구 : 83
# 평균 : -0.01744826850600567 표준편차 : 17.569654141469993
# 이상치 성북구 : 83
# 평균 : -0.017312400321000062 표준편차 : 19.144064784636427
# 이상치 중랑구 : 84
# 평균 : -0.017288274194693313 표준편차 : 17.557617969351856
# 이상치 강북구 : 78
# 평균 : -0.013354445810177563 표준편차 : 17.73551126056407
# 이상치 양천구 : 94
# 평균 : -0.018158084537942706 표준편차 : 18.66478572568133
# 이상치 도봉구 : 71
# 평균 : -0.015091526904436369 표준편차 : 18.663182408593617
# 이상치 은평구 : 81
# 평균 : -0.011200871588054918 표준편차 : 17.651786158789054
# 이상치 용산구 : 79
# 평균 : -0.014668684795965633 표준편차 : 18.748115978812358
# 이상치 광진구 : 84

# %%
for i in df.columns[1:]:
  df[i] = df[i].interpolate()

df = df.reset_index(drop = True)

df.to_csv('/content/drive/MyDrive/Proj_WT/DataSets/airpolution/2.5-sigma ztest.csv', encoding = 'utf-8', index = False)

# %%
# 주기성을 확실히 띄는 것을 알 수 있다.
# result.seasonal[:200].plot()

# %%
# 이상치를 제거해주고 데이터의 분포를 확인한다.
for i in df.columns[1:]:
  plt.figure(figsize = (16,8))
  sns.distplot(df[i])
  plt.show()

# %%
# log를 하고 데이터의 분포를 확인한다.
for i in df.columns[1:]:
  plt.figure(figsize =(16,8))
  sns.distplot(df[i].apply(lambda x: np.log1p(x)))
  plt.show()

# %%
df
# Out:
#            측정일자  동대문구   종로구    중구   성동구  ...   양천구   도봉구   은평구   용산구   광진구
# 0    2010-01-01  35.0  36.0  33.0  31.0  ...  36.0  31.0  29.0  34.0  32.0
# 1    2010-01-02  50.0  53.0  48.0  51.0  ...  62.0  44.0  47.0  51.0  45.0
# 2    2010-01-03  50.0  44.0  48.0  46.0  ...  50.0  49.0  47.0  49.0  46.0
# 3    2010-01-04  38.0  43.0  37.0  38.0  ...  43.0  33.0  35.0  38.0  34.0
# 4    2010-01-05  49.0  48.0  49.0  50.0  ...  53.0  46.0  48.0  51.0  48.0
# ...         ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 4013 2020-12-27  59.0  70.0  75.0  59.0  ...  67.0  61.0  62.0  66.0  61.0
# 4014 2020-12-28  59.0  66.0  73.0  57.0  ...  65.0  59.0  57.0  52.0  59.0
# 4015 2020-12-29  60.0  69.0  78.0  60.0  ...  77.0  62.0  65.0  74.0  60.0
# 4016 2020-12-30  30.0  39.0  38.0  30.0  ...  33.0  30.0  37.0  44.0  32.0
# 4017 2020-12-31  21.0  28.0  38.0  22.0  ...  29.0  20.0  26.0  34.0  24.0
#
# [4018 rows x 26 columns]

# %%
from scipy.stats import shapiro
# 정규성 검정은 여전히 안되는 구나!
alpha = 0.05
Gaussian_distribution = []
for i in df.columns[1:]:
  stat, p = shapiro(df[i].apply(lambda x: np.log1p(x)))
  print(f'{i} and {p}')
  if p > alpha:
    Gaussian_distribution.append(i)

print(Gaussian_distribution)
# Out:
# 동대문구 and 3.449539692459668e-17
# 종로구 and 3.004512304285015e-19
# 중구 and 1.6058454013488156e-15
# 성동구 and 8.102397985115768e-19
# 금천구 and 3.33456606070755e-15
# 송파구 and 1.968956752870725e-20
# 관악구 and 3.011832591052338e-13
# 강동구 and 7.954899873975098e-23
# 서대문구 and 6.547877820990722e-25
# 노원구 and 5.1470526140168997e-17
# 마포구 and 1.1909389944694482e-17
# 동작구 and 2.0418123788945586e-11
# 서초구 and 6.912264813681639e-22
# 구로구 and 2.944053510745059e-23
# 영등포구 and 3.0358431100180534e-16
# 강남구 and 1.4481818045362676e-19
# 강서구 and 1.4992973012420112e-19
# 성북구 and 9.473798817243332e-16
# 중랑구 and 3.598514353386267e-22
# 강북구 and 2.2168666598619887e-21
# 양천구 and 6.85144292198205e-19
# 도봉구 and 4.3226879414039133e-19
# 은평구 and 2.543978787387778e-20
# 용산구 and 1.5147866846387176e-24
# 광진구 and 1.0952461504376937e-22
# []
