# %% [markdown]
# # 데이터 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/airpolution/interpolate_linear.csv', parse_dates = ['측정일자'])
df.head()
# Out:
#         측정일자  동대문구   종로구    중구   성동구   금천구  ...   강북구   양천구   도봉구   은평구   용산구   광진구
# 0 2010-01-01  35.0  36.0  33.0  31.0  33.0  ...  33.0  36.0  31.0  29.0  34.0  32.0
# 1 2010-01-02  50.0  53.0  48.0  51.0  56.0  ...  47.0  62.0  44.0  47.0  51.0  45.0
# 2 2010-01-03  50.0  44.0  48.0  46.0  45.0  ...  44.0  50.0  49.0  47.0  49.0  46.0
# 3 2010-01-04  38.0  43.0  37.0  38.0  38.0  ...  37.0  43.0  33.0  35.0  38.0  34.0
# 4 2010-01-05  49.0  48.0  49.0  50.0  45.0  ...  40.0  53.0  46.0  48.0  51.0  48.0
#
# [5 rows x 26 columns]

# %%
df = df.drop([0,1], axis = 0).reset_index(drop = True)

# %%
train = df[df['측정일자'] < '2019']
test = df[(df['측정일자'] >= '2019') & (df['측정일자']< '2020')]

# %%
# import numpy as np
# def create_dataset(dataset, look_back=9):
#   dataX, dataY = [], []
#   for i in range(len(dataset)-look_back-1):
#     dataset = pd.DataFrame(dataset)
#     a = dataset.iloc[i:(i+look_back),0]
#     dataX.append(a)
#     dataY.append(dataset.iloc[i + look_back, 0])
#   return np.array(dataX), np.array(dataY)

# look_back = 365
# X_train_data = {}
# X_test_data = {}
# y_train_data = {}
# y_test_data = {}
# for j in df.columns[1:]:
#   X_train, y_train = create_dataset(train[j], look_back)
#   X_test, y_test = create_dataset(test[j], look_back)

#   X_train_data[j] = X_train
#   X_test_data[j] = X_test
#   y_train_data[j] = y_train
#   y_test_data[j] = y_test

# %% [markdown]
# # 데이터 전처리

# %%
train.shape, test.shape
# Out:
# ((3285, 26), (365, 26))

# %%
Window_size = 30
Test_size = 300

train_data = {}
test_data = {}
train_label = {}
X_train_data = {}
X_valid_data = {}

final_train_data = {}
for i in train.columns[1:]:
  train_data[i] = train[i][:-Test_size]
  train_label[i] = train[i][-Test_size:]
  
  label_list = []
  for j in range(len(train_data[i]) - Window_size):
    label_list.append(np.array(train_data[i][j+Window_size]))
    
  final_train_data[i] = np.array(label_list)


  # test_data[i] = test[i].values[:-365]





# for i in train.columns[1:]:
#   train_label = make_dataset(train_data[i], i, 365)

#   print(train_label)

# %%
final_train_data['동대문구'].shape
# Out:
# (2955,)

# %%
train_data['동대문구'].shape
# Out:
# (2985,)

# %% [markdown]
# # Modeling

# %% [markdown]
# # LSTM

# %%
X_tr

# %%
X_train.shape
# Out:
# (3275, 1, 9)

# %%
X_train_data['동대문구'].shape
# Out:
# (3275, 9)

# %%
import tensorflow
from sklearn.preprocessing import RobustScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Flatten, BatchNormalization

for i in X_train_data.keys():
  X_train = np.reshape(X_train_data[i], (X_train_data[i].shape[0], X_train_data[i].shape[1],1 ))
  X_test = np.reshape(X_test_data[i], (X_test_data[i].shape[0], X_test_data[i].shape[1],1 ))
  model = Sequential()
  model.add(LSTM(512, activation = 'relu', input_shape = (X_train[2],X_train[1],), return_sequences = True))
  model.add(Dropout(0.2))
  model.add(LSTM(256, activation = 'relu'))
  model.add(Dense(1))

  model.summary()
  model.compile(loss = 'mean_squared_error', optimizer = 'adam')
  model.fit(X_train[i], y_train[i], epochs = 10, batch_size = 512)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-1f46df6ace32> in <module>()
#       8   X_test = np.reshape(X_test_data[i], (X_test_data[i].shape[0], X_test_data[i].shape[1],1 ))
#       9   model = Sequential()
# ---> 10   model.add(LSTM(512, activation = 'relu', input_shape = (X_train[2],X_train[1],), return_sequences = True))
#      11   model.add(Dropout(0.2))
#      12   model.add(LSTM(256, activation = 'relu'))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     520     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521     try:
# --> 522       result = method(self, *args, **kwargs)
#     523     finally:
#     524       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ...

# %%
train_data.eys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-61253cb2e2fd> in <module>()
# ----> 1 train_data.eys()
#
# AttributeError: 'dict' object has no attribute 'eys'

# %%
train_data[i].shape
# Out:
# (45, 73, 1)

# %%
np.arange(1)
# Out:
# array([0])
