# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/airpolution/WholeData.csv')
df.head()
# Out:
#          측정일자  동대문구   종로구    중구   성동구   금천구  ...   강북구   양천구   도봉구   은평구   용산구   광진구
# 0  2010-01-01  35.0  36.0  33.0  31.0  33.0  ...  33.0  36.0  31.0  29.0  34.0  32.0
# 1  2010-01-02  50.0  53.0  48.0  51.0  56.0  ...  47.0  62.0  44.0  47.0  51.0  45.0
# 2  2010-01-03  50.0  44.0  48.0  46.0  45.0  ...  44.0  50.0  49.0  47.0  49.0  46.0
# 3  2010-01-04  38.0  43.0  37.0  38.0  38.0  ...  37.0  43.0  33.0  35.0  38.0  34.0
# 4  2010-01-05  49.0  48.0  49.0  50.0  45.0  ...  40.0  53.0  46.0  48.0  51.0  48.0
#
# [5 rows x 26 columns]

# %%
test_dataframe =  df[df.columns[0]]

# %%
column = df.columns[1:]
column
column = ['Dongdaemungu','Jongnogu','Junggu','Seongdonggu','Geumcheongu','Songpagu','Gwanakgu','Gangdonggu','Seodaemungu','Nowongu','Mapogu','Dongjakgu','Seochogu','Gurogu',
          'Yeongdeungpogu','Gangnamgu','Gangseogu','Seongbukgu','Jungnanggu','Gangbukgu','Yangcheongu','Dobonggu','Eunpyeonggu','Yongsangu','Gwangjingu']

# %%
PATH = '/content/drive/MyDrive/Proj_WT/DataSets/airpolution/'
a = '_Actual.csv'
for i in column:
    data=pd.read_csv(PATH + i + a)
    data = data.drop('측정일자', axis = 1)    
    test_dataframe = pd.concat([test_dataframe, data], axis= 1)

# /content/drive/MyDrive/Proj_WT/DataSets/airpolution/Gangdonggu_Actual.csv
# /content/drive/MyDrive/Proj_WT/DataSets/airpolution/GangDonggu_Actual.csv

# %%
test_dataframe.to_csv(PATH + 'test_dataframe.csv', index = False, encoding = 'utf-8')
