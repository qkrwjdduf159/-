# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

data = pd.read_excel('/content/drive/MyDrive/sd솔데스크/팀 프로젝트/201101201912.xls')
data.head()
# Out:
#      시도   군구         관광지  ... Unnamed: 119  Unnamed: 120 Unnamed: 121
# 0   NaN  NaN         NaN  ...    2019년 10월     2019년 11월    2019년 12월
# 1  충청북도  청주시     국립청주박물관  ...        50205         28468        23658
# 2  충청북도  청주시     국립청주박물관  ...           95            40           11
# 3  충청북도  청주시     국립청주박물관  ...        50300         28508        23669
# 4  충청북도  청주시  국립현대미술관 청주  ...        32076         25037        21314
#
# [5 rows x 122 columns]

# %%
# 데이터 전처리 하기
data = data.T
data = data.reset_index(drop = True)
data.head(10)
for i in data.iloc[:,2:].columns:
  if data.loc[3,i] != '내국인':
    data = data.drop(i, axis = 1)

data.columns = data.loc[2,:]
data = data.drop([0,1,2,3,4,5], axis = 0)

# %%
data = data.rename(columns = {np.nan:'date'})
data = data.reset_index(drop = True)
data
# Out:
# 2         date 국립청주박물관 국립현대미술관 청주 동래부사송상현충렬사  ... 증평대장간 증평민속체험박물관 증평유스호스텔 충북인삼유통센터
# 0    2011년 01월   10567        NaN        NaN  ...  3444      1001    3500     3565
# 1    2011년 02월   15967        NaN        NaN  ...  3285      1940    3000     3476
# 2    2011년 03월    9117        NaN        NaN  ...  4092      2050    3000     3689
# 3    2011년 04월   25477        NaN        NaN  ...  3264      2138    3000     3597
# 4    2011년 05월   63529        NaN        NaN  ...  3501      1767    3000     3814
# ..         ...     ...        ...        ...  ...   ...       ...     ...      ...
# 111  2019년 08월   47584      21058        NaN  ...   NaN      2504     NaN     1941
# 112  2019년 09월   49837      17493        NaN  ...   NaN      2687     NaN     2519
# 113  2019년 10월   50205      32076        NaN  ...   NaN      3602     NaN     2845
# 114  2019년 11월   28468      25037        NaN  ...   NaN      1728     NaN     2158
# 115  2019년 12월   23658      21314        NaN  ...   NaN      2270     NaN     2220
#
# [116 rows x 375 columns]

# %%
# 컬럼 reset
# 충북 = {}
# 청주시 = pd.DataFrame([])
# 충주시 = pd.DataFrame([])
# 제천시 = pd.DataFrame([])
# 청원군 = pd.DataFrame([])
# 보은군 = pd.DataFrame([])
# 옥천군 = pd.DataFrame([]) 
# 영동군 = pd.DataFrame([])
# 진천군 = pd.DataFrame([])
# 괴산군 = pd.DataFrame([])
# 음성군 = pd.DataFrame([])
# 단양군 = pd.DataFrame([]) 
# 증평군 = pd.DataFrame([])

# for j in range(len(data.columns)):
#   if data.iloc[0,j] == '청주시':
#     청주시 =  pd.concat([청주시,data.iloc[:,j]], axis = 1)
#     충북['청주시'] = 청주시
#   elif data.iloc[0,j] == '충주시':
#     충주시 = pd.concat([충주시,data.iloc[:,j]], axis = 1)
#     충북['충주시'] = 충주시
#   elif data.iloc[0,j] == '제천시':
#     제천시 = pd.concat([제천시, data.iloc[:,j]], axis = 1)
#     충북['제천시'] = 제천시
#   elif data.iloc[0,j] == '청원군':
#     청원군=pd.concat([청원군, data.iloc[:,j]], axis = 1)
#     충북['청원군'] = 청원군
#   elif data.iloc[0,j] == '보은군':
#     보은군=pd.concat([보은군, data.iloc[:,j]], axis = 1)
#     충북['보은군'] = 보은군
#   elif data.iloc[0,j] == '옥천군':
#     옥천군 = pd.concat([옥천군, data.iloc[:,j]], axis = 1)
#     충북['옥천군'] = 옥천군
#   elif data.iloc[0,j] == '영동군':
#     영동군 = pd.concat([영동군, data.iloc[:,j]], axis = 1)
#     충북['영동군'] = 영동군
#   elif data.iloc[0,j] == '진천군':
#     진천군 = pd.concat([진천군, data.iloc[:,j]], axis = 1)
#     충북['진천군'] = 진천군
#   elif data.iloc[0,j] == '괴산군':
#     괴산군 = pd.concat([괴산군, data.iloc[:,j]], axis = 1)
#     충북['괴산군'] = 괴산군
#   elif data.iloc[0,j] == '음성군':
#     음성군 = pd.concat([음성군, data.iloc[:,j]], axis = 1)
#     충북['음성군'] = 음성군
#   elif data.iloc[0,j] == '단양군':
#     단양군 = pd.concat([단양군, data.iloc[:,j]], axis = 1)
#     충북['단양군'] = 단양군
#   elif data.iloc[0,j] == '증평군':
#     증평군 =  pd.concat([증평군,data.iloc[:,j]], axis = 1)
#     충북['증평군'] = 증평군
#   else:
#     pass

# %%
# for i in 충북:
#   충북[i] = pd.concat([충북[i],data.loc[:,0]], axis = 1)
#   충북[i].columns = 충북[i].loc[2,:]
  # 충북[i]=충북[i].rename(columns = {np.nan:'date'})
  # 충북[i] = 충북[i].drop([1,2,5],axis = 0)

# %% [markdown]
# # 날씨 데이터 불러오기

# %%
충북1112 = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS/1112/청주기상지청.csv')
충북1314 = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS/1314/청주기상지청.csv')
충북1516 = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS/1516/청주기상지청.csv')
충북1718 = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS/1718/청주기상지청.csv')
충북19 = pd.read_csv('/content/drive/MyDrive/Proj_WT/DataSets/기상청_일별_지상_종관_ASOS/1920/청주기상지청.csv')

# %%
# 충북19 = 충북19.drop(['지점 번호','지점명','일기현상'], axis = 1)
충북19['일시'] = 충북19['일시'].apply(lambda x:str(x)[:7])
충북19['일시'] = 충북19['일시'].apply(lambda x:x.replace('-',''))
충북19['일시'] = 충북19['일시'].astype('int')
충북19 = 충북19[충북19['일시'] <= 201912]
충북19['일시'] = 충북19['일시'].astype('str')
충북19 = 충북19.groupby('일시')['평균 기온(°C)', '최저 기온(°C)', '최저 기온 시각(hhmi)', '최고 기온(°C)',
       '최고 기온 시각(hhmi)', '강수 계속시간(hr)', '10분 최다강수량(mm)', '10분 최다강수량 시각(hhmi)',
       '1시간 최다강수량(mm)', '1시간 최다강수량 시각(hhmi)', '일강수량(mm)', '최대 순간풍속(m/s)',
       '최대 순간풍속 풍향(16방위)', '최대 순간풍속 시각(hhmi)', '최대 풍속(m/s)', '최대 풍속 풍향(16방위)',
       '최대 풍속 시각(hhmi)', '평균 풍속(m/s)', '풍정합(100m)', '최다 풍향(16방위)',
       '평균 이슬점온도(°C)', '최소 상대습도(%)', '평균 상대습도 시각(hhmi)', '평균 상대습도(%)',
       '평균 중기압(hPa)', '평균 현지기압(hPa)', '최고 해면 기압(hPa)', '최고 해면기압 시각(hhmi)',
       '최저 해면기압(hPa)', '최저 해면기압 시각(hhmi)', '평균 해면기압(hPa)', '가조시간(hr)',
       '합계 일조 시간(hr)', '1시간 최다 일사 시각(hhmi)', '1시간 최다 일사량(MJ/m2)',
       '합계 일사량(MJ/m2)', '일 최심신적설(cm)', '일 최심신적설 시각(hhmi)', '일 최심적설(cm)',
       '일 최심적설 시각(hhmi)', '합계 3시간 신적설(cm)', '평균 전운량(10분위)', '평균 중하층운량(10분위)',
       '평균 지면온도(°C)', '최저 초상온도(°C)', '평균 5cm 지중온도(°C)', '평균 10cm 지중온도(°C)',
       '평균 20cm 지중온도(°C)', '평균 30cm 지중온도(°C)', '0.5m 지중온도(°C)',
       '1.0cm 지중온도(°C)', '1.5cm 지중온도(°C)', '3.0cm 지중온도(°C)', '5.0cm 지중온도(°C)',
       '합계 대형증발량(mm)', '합계 소형증발량(mm)', '9-9강수(mm)', '안개 계속 시간(hr)'].mean()

# %%
def weather_go(data = None):
  data = data.drop(['지점 번호','지점명','일기현상'], axis = 1)
  data['일시'] = data['일시'].apply(lambda x:str(x)[:7])
  data['일시'] = data['일시'].apply(lambda x:x.replace('-',''))
  
  
  data=data.groupby('일시')['평균 기온(°C)', '최저 기온(°C)', '최저 기온 시각(hhmi)', '최고 기온(°C)',
       '최고 기온 시각(hhmi)', '강수 계속시간(hr)', '10분 최다강수량(mm)', '10분 최다강수량 시각(hhmi)',
       '1시간 최다강수량(mm)', '1시간 최다강수량 시각(hhmi)', '일강수량(mm)', '최대 순간풍속(m/s)',
       '최대 순간풍속 풍향(16방위)', '최대 순간풍속 시각(hhmi)', '최대 풍속(m/s)', '최대 풍속 풍향(16방위)',
       '최대 풍속 시각(hhmi)', '평균 풍속(m/s)', '풍정합(100m)', '최다 풍향(16방위)',
       '평균 이슬점온도(°C)', '최소 상대습도(%)', '평균 상대습도 시각(hhmi)', '평균 상대습도(%)',
       '평균 중기압(hPa)', '평균 현지기압(hPa)', '최고 해면 기압(hPa)', '최고 해면기압 시각(hhmi)',
       '최저 해면기압(hPa)', '최저 해면기압 시각(hhmi)', '평균 해면기압(hPa)', '가조시간(hr)',
       '합계 일조 시간(hr)', '1시간 최다 일사 시각(hhmi)', '1시간 최다 일사량(MJ/m2)',
       '합계 일사량(MJ/m2)', '일 최심신적설(cm)', '일 최심신적설 시각(hhmi)', '일 최심적설(cm)',
       '일 최심적설 시각(hhmi)', '합계 3시간 신적설(cm)', '평균 전운량(10분위)', '평균 중하층운량(10분위)',
       '평균 지면온도(°C)', '최저 초상온도(°C)', '평균 5cm 지중온도(°C)', '평균 10cm 지중온도(°C)',
       '평균 20cm 지중온도(°C)', '평균 30cm 지중온도(°C)', '0.5m 지중온도(°C)',
       '1.0cm 지중온도(°C)', '1.5cm 지중온도(°C)', '3.0cm 지중온도(°C)', '5.0cm 지중온도(°C)',
       '합계 대형증발량(mm)', '합계 소형증발량(mm)', '9-9강수(mm)', '안개 계속 시간(hr)'].mean()

  return data

충북1112 = weather_go(충북1112)
충북1314 = weather_go(충북1314)
충북1516 = weather_go(충북1516)
충북1718 = weather_go(충북1718)

# %%
충북데이터 = pd.DataFrame([])
for i in [충북1112,충북1314,충북1516,충북1718,충북19]:
  충북데이터 = pd.concat([충북데이터,i], axis = 0)
충북데이터 = 충북데이터.reset_index().rename(columns = {'일시':'date'})
충북데이터 = 충북데이터.dropna(axis = 1)

# %%
충북데이터
# Out:
#        date  평균 기온(°C)  최저 기온(°C)  ...  최저 초상온도(°C)  합계 소형증발량(mm)  9-9강수(mm)
# 0    201101  -7.569032 -13.343226  ...   -13.656129      1.112903   0.264706
# 1    201102   0.335714  -5.542857  ...    -8.884286      1.457143   9.740000
# 2    201103   3.262581  -2.604516  ...    -6.162581      2.677419   3.000000
# 3    201104  10.542000   3.786000  ...     0.642000      3.833333   7.481250
# 4    201105  17.321290  11.363226  ...     8.880645      4.245161  10.308333
# ..      ...        ...        ...  ...          ...           ...        ...
# 103  201908  25.766452  21.545161  ...    20.776774      5.517742   5.750000
# 104  201909  21.030000  16.705333  ...    15.781333      3.763333  11.930769
# 105  201910  14.380645   9.080645  ...     7.243226      3.453226  12.042857
# 106  201911   6.746667   0.878667  ...    -1.897333      2.618644  12.975000
# 107  201912   0.425806  -4.258065  ...    -7.000000      1.664516   1.566667
#
# [108 rows x 39 columns]

# %%
# 충북데이터
data['date'] = data['date'].apply(lambda x:x.replace('년','').replace('월',''))
data['date'] = data['date'].apply(lambda x:x.replace(' ',''))

# %%
final_data = pd.merge(충북데이터, data, how = 'left', on = 'date')

# %%
# 201701 ~ 201912에 데이터가 없는 데이터는 제거해준다.
a = []
for i,j in enumerate(final_data[final_data['date'] >= '201701'].isnull().sum()):
  if j != 0:
    a.append(i)
final_data =final_data.drop(final_data.columns[a], axis = 1)

# %% [markdown]
# # Modeling

# %%
# !pip3 install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels) (2018.9)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

x_column = 충북데이터.columns[1:]
y_column = final_data.columns[len(충북데이터.columns):]

# %%
# 지금 우리가 있는 데이터인 2017~2019의 데이터를 가지고 분석을 진행해보기로 하자.
# train과 test로 데이터를 나눈다.
train = final_data[(final_data['date'] >= '201701') & (final_data['date'] <= '201812')]
test = final_data[(final_data['date'] >= '201901')]

# 분석하기 용이하게 데이터를 학습 데이터와 타겟 데이터로 나눠준다.
X_train = train[x_column]
y_train = train[y_column]

X_test = test[x_column]
y_test = test[y_column]

# %%
# 모델을 돌려줄 데이터의 shape과 결측치를 살펴본다.
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print(X_train.isnull().sum().sum(),
      X_test.isnull().sum().sum(),
      y_train.isnull().sum().sum(),
      y_test.isnull().sum().sum())
# Out:
# (24, 38) (12, 38) (24, 130) (12, 130)
# 0 0 0 0

# %%
target_column = y_train.columns
for i in target_column:
  model = LinearRegression()
  model.fit(X_train, y_train[i])
  y_pred = model.predict(X_test)
  RMSE = mean_squared_error(y_test[i], y_pred) ** 0.5
  print(f'{i}',RMSE)
# Out:
# 국립청주박물관 64340.15064057189
# 문암생태공원 캠핑장 690.2154133867488
# 상당산성 자연휴양림 4886.448004930062
# 우암어린이회관 39024.35444084833
# 청주동물원 21690.95208145143
# 계명산자연휴양림 3289.9678472058863
# 고구려비전시관 2587.1171992140853
# 목계나루 1977.8742206820145
# 문성자연휴양림 3535.1150022614593
# 봉황자연휴양림 3600.459098004869
# 선사박물관 1226.6345883908293
# 세계무술박물관 6473.804957155087
# 센테리움CC 9632.861167611933
# 수안보온천지구(수안보상록호텔 온천이용) 24697.57556112198
# 수안보온천지구(수안보파크호텔 온천이용) 8048.057149764493
# 수안보온천지구(하이스파 온천이용) 11781.022881225392
# 수안보온천지구(한화콘도 온천이용) 3383.0667103622254
# 앙성온천지구(앙성탄산온천 온천이용) 2023.9944819308203
# 월악산국립공원(만수골) 3879.5476071705125
# 임페리얼레이크컨트리클럽 1913.2533257572954
# 중원골프장 8708.360671249518
# 충주고구려천문과학관 969.902403769283
# 충주박물관 11657.69359581714
# 충주시 자연생태체험관 1846.1661311715955
# 충주월악파3 골프장 296.4502091305872
# 충주호관광선 5888.903250493695
# 풍류문화관 2235.096796798365
# 리솜포레스트 아쿠아존 7431.5019726828805
# 만남의광장 34616.39562796298
# 박달재자연휴양림 1383.5630258361664
# 박달재청소년수련원 4355.337866703551
# 배론성지 48390.35862386607
# 월악꽃단지마을 1312.6202276475985
# 월악산국립공원(덕산) 5707.6870072466945
# 월악산국립공원(덕주골) 3872.001659749161
# 월악산국립공원(동창교) 2903.980071207417
# 월악산국립공원(북바위산) 2503.84849778189
# 월악산국립공원(송계) 6041.018626646097
# 월악유스호스텔 1003.5298433482322
# 의림지 101511.18189490058
# 자연탐사과학관 1783.5667954668027
# 제천시 청소년 수련원 2113.9919067521223
# 제천시산악체험장 414.0280612864745
# 청풍문화재단지 21809.808450350516
# 청풍유람선 11231.621907945493
# 청풍유스호스텔 1026.7569780632173
# 청풍호 관광모노레일 6702.6096358976665
# 청풍호자드락1길(작은동산길) 16104.424545003705
# 청풍호자드락3길(얼음골생태길) 17932.97169749331
# 청풍호자드락6길(괴곡성벽길) 16074.014836884704
# 동학농민혁명기념공원 8454.877154924689
# 말티재자연휴양림 4511.094902374025
# 별방유스타운 2529.247527913186
# 삼년산성 1280.769288318936
# 서당골청소년수련원관광농원 3393.241745277815
# 선병국가옥 1689.7337401563627
# 속리산국립공원(법주사) 58802.92900065788
# 속리산알프스수련원 1173.7130421319416
# 속리산유스타운 6107.027277019899
# 솔향공원 29375.86577320228
# 오장환문학관 919.8476391125157
# 충북알프스자연휴양림 4223.794690856046
# 펀파크 2324.346797140908
# 육영수생가 3867.458802095123
# 장계관광지 1553.4989342134793
# 장령산 자연휴양림 10516.457963225692
# 정지용문학관 4661.304870297568
# 국악체험촌 14352.801460974475
# 난계국악박물관 5940.7429032565
# 민주지산 2780.8967353102967
# 민주지산(영동군)자연휴양림 6241.475113107267
# 반야사 7271.916065683333
# 송호관광지 3830.7159818875066
# 옥계폭포 3999.9428558462805
# 월류봉 10391.687890482279
# 천태산 8465.454259762837
# 길상사 638.2728643713588
# 김유신장군탄생지 297.57242885156586
# 만뢰산자연생태공원 1504.1459639189973
# 문강도예캠프 3813.120977783533
# 배티성지 6499.990340448917
# 아트밸리 컨트리클럽 1789.6519395924047
# 안골관광농원 242.8766892364398
# 에머슨컨트리클럽 5616.751283850423
# 진천군 청소년수련원 2724.652326862614
# 진천농교(농다리) 23227.46505649093
# 진천종박물관 2492.9079650516446
# 천룡컨트리클럽 5240.376010228842
# 크리스탈카운티컨트리클럽 1776.851483907201
# 히든밸리 골프클럽 5764.50819982505
# 괴강관광지(괴산청소년수련관) 1964.6481377486307
# 괴강관광지(국민여가캠핑장) 927.8101644473917
# 괴산한지체험박물관 428.6306921952948
# 보람원 4387.108464940663
# 산막이옛길 83733.07594161709
# 성불산자연휴양림 3851.5236633450722
# 속리산국립공원(갈론구곡) 5370.580948269983
# 속리산국립공원(공림사) 5320.339727121657
# 속리산국립공원(선유구곡) 4862.8167072643255
# 속리산국립공원(쌍곡구곡) 9503.5726450885
# 속리산국립공원(화양구곡) 8036.3021778110715
# 연하협구름다리 24175.72094351296
# 조령산자연휴양림 1340.7030032170076
# 무극전적국민관광지 1501.8334807996232
# 반기문 평화기념관 2672.7845102296837
# 코리아크래프트브류어리 176.7562471823386
# 고수동굴 17047.382517496146
# 구담봉 75959.92837644804
# 구인사 104888.136122621
# 다누리아쿠아리움 9190.771404120578
# 다리안관광지 38797.364771030974
# 단양수양개선사유적전시관 21557.437890402674
# 도담삼봉 251717.39386569714
# 사인암 86385.89995799147
# 소노문 단양 오션플레이 4249.046821473674
# 소백산국립공원 북부사무소(죽령) 18114.495099199627
# 소백산국립공원 북부사무소(천동) 20087.03136196881
# 소백산국립공원 북부출장소(어의곡) 11863.235000312236
# 소선암자연휴양림(오토캠핑장 포함) 2180.89140921797
# 온달관광지 15798.934353301496
# 월악산국립공원 단양분소(금수산) 21807.583866220706
# 월악산국립공원 단양분소(도락산) 2311.1795469679373
# 월악산국립공원 단양분소(제비봉) 4110.794895845747
# 천동관광지 2495.341325816171
# 황정산자연휴양림 2031.8935881822279
# 율리휴양촌 13762.291300723962
# 좌구산휴양림 33769.19819996912
# 증평 좌구산천문대 3283.717274881441
# 증평민속체험박물관 6778.3510745292315
# 충북인삼유통센터 1143.6700865991124
